# %% [markdown]
# ***

# %% [markdown]
# ### IoT DDoS Detection Based on Ensemble Methods for Evolving Data Stream Classification
#
# Kétly Gonçalves Machado (<ketly@ime.usp.br>) and Daniel Macêdo Batista (<batista@ime.usp.br>)
#
# [Department of Computer Science](https://www.ime.usp.br/en/computer-science-department/)
#
# University of São Paulo
#
# São Paulo, Brazil

# %% [markdown]
# ***

# %% [markdown]
# ### BoT-IoT Dataset

# %% [markdown]
# In our work we used the [BoT-IoT dataset](https://research.unsw.edu.au/projects/bot-iot-dataset) to perform the analysis of ensemble methods for evolving data stream classification. The dataset was released in 2018 by the Cyber Range Lab of UNSW Canberra and presents realistic IoT network traffic that incorporates a combination of normal and attack instances.
#
# The testbed used to construct the dataset consists of three components: (i) network platforms, that include normal and attacking virtual machines, an Ubuntu server, Ubuntu mobile, Windows 7, Metasploitable and an Ubuntu Tap machine; (ii) simulated IoT services deployed in the Ubuntu server, that reproduce a weather station, a smart fridge, motion activated lights, a remotely activated garage door and a smart thermostat. To simulate the network behavior of the devices, the authors employed the [Node-red tool](https://nodered.org/). Also, the five scenarios were connected to the Ubuntu server where a [Mosquitto MQTT broker](https://mosquitto.org/) was installed, and to the [AWS IoT hub](https://aws.amazon.com/iot/); and (iii) extracting features and forensics analytics, where the [Argus tool](https://openargus.org/) was used to extract data features, and also statistical models and machine learning techniques were employed to distinguish normal and attack instances.
#
# The dataset original files, including pcap, argus and csv formats, are available [here](https://cloudstor.aarnet.edu.au/plus/s/umT99TnxvbpkkoE). The captured pcap files are 69.4 GB in size, with more than 72 million records. The extracted flow traffic, in csv format, is 17.4 GB in size. It includes Service Scanning, OS Fingerprint, DDoS, DoS, Keylogging and Data Theft attacks, with the DDoS and DoS attacks also divided by protocol.

# %% [markdown]
# We used the entire original BoT-IoT dataset that contains a total of 35 features which are presented in the following table, where the feature **attack** is the class label that divides the traffic into normal and attack instances.

# %% [markdown]
# <table>
#     <tr>
#         <th style="text-align:center;background-color: #4dd0e1">Feature</th>
#         <th style="text-align:center;background-color: #4dd0e1">Description</th>
#         <th style="text-align:center;background-color: #4dd0e1">Feature</th>
#         <th style="text-align:center;background-color: #4dd0e1">Description</th>
#         <th style="text-align:center;background-color: #4dd0e1">Feature</th>
#         <th style="text-align:center;background-color: #4dd0e1">Description</th>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">pkSeqID</td>
#         <td style="text-align:center;background-color: #e0f7fa">Row Identifier</td>
#         <td style="text-align:center;background-color: #e0f7fa">seq</td>
#         <td style="text-align:center;background-color: #e0f7fa">Argus sequence number</td>
#         <td style="text-align:center;background-color: #e0f7fa">dco</td>
#         <td style="text-align:center;background-color: #e0f7fa">-</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">stime</td>
#         <td style="text-align:center;background-color: #b2ebf2">Record start time</td>
#         <td style="text-align:center;background-color: #b2ebf2">dur</td>
#         <td style="text-align:center;background-color: #b2ebf2">Record total duration</td>
#         <td style="text-align:center;background-color: #b2ebf2">spkts</td>
#         <td style="text-align:center;background-color: #b2ebf2">Source-to-destination packet count</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">flgs</td>
#         <td style="text-align:center;background-color: #e0f7fa">Flow state flags seen in transactions</td>
#         <td style="text-align:center;background-color: #e0f7fa">mean</td>
#         <td style="text-align:center;background-color: #e0f7fa">Average duration of aggregated records</td>
#         <td style="text-align:center;background-color: #e0f7fa">dpkts</td>
#         <td style="text-align:center;background-color: #e0f7fa">Destination-to-source packet count</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">proto</td>
#         <td style="text-align:center;background-color: #b2ebf2">Textual representation of transaction protocols present in network flow</td>
#         <td style="text-align:center;background-color: #b2ebf2">stddev</td>
#         <td style="text-align:center;background-color: #b2ebf2">Standard deviation of aggregated records</td>
#         <td style="text-align:center;background-color: #b2ebf2">sbytes</td>
#         <td style="text-align:center;background-color: #b2ebf2">Source-to-destination byte count</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">saddr</td>
#         <td style="text-align:center;background-color: #e0f7fa">Source IP address</td>
#         <td style="text-align:center;background-color: #e0f7fa">smac</td>
#         <td style="text-align:center;background-color: #e0f7fa">-</td>
#         <td style="text-align:center;background-color: #e0f7fa">dbytes</td>
#         <td style="text-align:center;background-color: #e0f7fa">Destination-to-source byte count</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">sport</td>
#         <td style="text-align:center;background-color: #b2ebf2">Source port number</td>
#         <td style="text-align:center;background-color: #b2ebf2">dmac</td>
#         <td style="text-align:center;background-color: #b2ebf2">-</td>
#         <td style="text-align:center;background-color: #b2ebf2">rate</td>
#         <td style="text-align:center;background-color: #b2ebf2">Total packets per second in transaction</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">daddr</td>
#         <td style="text-align:center;background-color: #e0f7fa">Destination IP address</td>
#         <td style="text-align:center;background-color: #e0f7fa">sum</td>
#         <td style="text-align:center;background-color: #e0f7fa">Total duration of aggregated records</td>
#         <td style="text-align:center;background-color: #e0f7fa">srate</td>
#         <td style="text-align:center;background-color: #e0f7fa">Source-to-destination packets per second</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">dport</td>
#         <td style="text-align:center;background-color: #b2ebf2">Destination port number</td>
#         <td style="text-align:center;background-color: #b2ebf2">min</td>
#         <td style="text-align:center;background-color: #b2ebf2">Minimum duration of aggregated records</td>
#         <td style="text-align:center;background-color: #b2ebf2">drate</td>
#         <td style="text-align:center;background-color: #b2ebf2">Destination-to-source packets per second</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">pkts</td>
#         <td style="text-align:center;background-color: #e0f7fa">Total count of packets in transaction</td>
#         <td style="text-align:center;background-color: #e0f7fa">max</td>
#         <td style="text-align:center;background-color: #e0f7fa">Maximum duration of aggregated records</td>
#         <td style="text-align:center;background-color: #e0f7fa"><b>attack</b></td>
#         <td style="text-align:center;background-color: #e0f7fa"><b>Class label: 0 for Normal traffic, 1 for Attack Traffic</b></td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">bytes</td>
#         <td style="text-align:center;background-color: #b2ebf2">Total number of bytes in transaction</td>
#         <td style="text-align:center;background-color: #b2ebf2">soui</td>
#         <td style="text-align:center;background-color: #b2ebf2">-</td>
#         <td style="text-align:center;background-color: #b2ebf2">category</td>
#         <td style="text-align:center;background-color: #b2ebf2">Traffic category</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #e0f7fa">state</td>
#         <td style="text-align:center;background-color: #e0f7fa">Transaction state</td>
#         <td style="text-align:center;background-color: #e0f7fa">doui</td>
#         <td style="text-align:center;background-color: #e0f7fa">-</td>
#         <td style="text-align:center;background-color: #e0f7fa">subcategory</td>
#         <td style="text-align:center;background-color: #e0f7fa">Traffic subcategory</td>
#     </tr>
#     <tr>
#         <td style="text-align:center;background-color: #b2ebf2">ltime</td>
#         <td style="text-align:center;background-color: #b2ebf2">Record last time</td>
#         <td style="text-align:center;background-color: #b2ebf2">sco</td>
#         <td style="text-align:center;background-color: #b2ebf2">-</td>
#         <td style="text-align:center;background-color: #b2ebf2"></td>
#         <td style="text-align:center;background-color: #b2ebf2"></td>
#     </tr>
# </table>

# %% [markdown]
# However, in our work, we are interested only at the normal and the DDoS instances of the dataset, except for the HTTP DDoS since our focus are volumetric attacks.
#
# Therefore, we performed an initial processing of the dataset to filter only the examples we want to classify within our research. That gave us the following amount of instances:
#
# * Normal instances: **9.543**
# * DDoS instances (TCP and UDP): **38.512.709**
# * Total: **38.522.252**

# %% [markdown]
# Following, we present our Exploratory Data Analysis (EDA) of the BoT-IoT dataset.
#
# Since the volume of data is significative, and due to memory limitation, we extracted a subset of the data that includes all normal instances plus 10% of the DDoS instances (TCP and UDP), randomly chosen, where each instance had 10% of chance to be included or not in the subset.

# %% [markdown]
# With this EDA we aimed to analyse the dataset mainly to perform feature selection, so we could further process the data to aquire a more appropriate final dataset for our experiments.

# %% [markdown]
# To do so, we used well-know python libraries and functions that helped us to better understand and deal with all information that BoT-IoT dataset contains.

# %% [markdown]
# #### References
#
# * Koroniotis, Nickolaos, Nour Moustafa, Elena Sitnikova, and Benjamin Turnbull. "Towards the development of realistic botnet dataset in the internet of things for network forensic analytics: Bot-iot dataset." Future Generation Computer Systems 100 (2019): 779-796. [Public Access Here](https://arxiv.org/abs/1811.00701).
#
# * Koroniotis, Nickolaos, Nour Moustafa, Elena Sitnikova, and Jill Slay. [Towards developing network forensic mechanism for botnet activities in the iot based on machine learning techniques"](https://link.springer.com/chapter/10.1007/978-3-319-90775-8_3). In International Conference on Mobile Networks and Management, pp. 30-44. Springer, Cham, 2017.
#
# * Koroniotis, Nickolaos, Nour Moustafa, and Elena Sitnikova. ["A new network forensic framework based on deep learning for Internet of Things networks: A particle deep framework"](https://www.sciencedirect.com/science/article/abs/pii/S0167739X19325105). Future Generation Computer Systems 110 (2020): 91-106.
#
# * Koroniotis, Nickolaos, and Nour Moustafa. ["Enhancing network forensics with particle swarm and deep learning: The particle deep framework"](https://arxiv.org/abs/2005.00722). arXiv preprint arXiv:2005.00722 (2020).
#
# * Koroniotis, Nickolaos, Nour Moustafa, Francesco Schiliro, Praveen Gauravaram, and Helge Janicke. ["A Holistic Review of Cybersecurity and Reliability Perspectives in Smart Airports"](https://ieeexplore.ieee.org/abstract/document/9252856). IEEE Access (2020).
#
# * Koroniotis, Nickolaos. ["Designing an effective network forensic framework for the investigation of botnets in the Internet of Things"](https://unsworks.unsw.edu.au/fapi/datastream/unsworks:69386/SOURCE02?view=true). PhD diss., The University of New South Wales Australia, 2020.

# %% [markdown]
# ### BoT-IoT Exploratory Data Analysis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns # statist graph package
import matplotlib.pyplot as plt # plot package

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 1000)

# %%
csv_file = "../processed-data/CSV/botiot-10-eda.csv"
df = pd.read_csv(csv_file)
# Out:
# /home/ketly/anaconda3/envs/IoT-Security-Research/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3170: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3860630 entries, 0 to 3860629
# Data columns (total 59 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pkSeqID      int64
#  1   stime        float64
#  2   flgs         object
#  3   proto        object
#  4   saddr        object
#  5   sport        object
#  6   daddr        object
#  7   dport        object
#  8   pkts         int64
#  9   bytes        int64
#  10  state        object
#  11  ltime        float64
#  12  seq          int64
#  13  dur          float64
#  14  mean         float64
#  15  stddev       float64
#  16  smac         float64
#  17  dmac         float64
#  18  sum          float64
#  19  min          float64
#  20  max          float64
#  21  soui         float64
#  22  doui         float64
#  23  sco          float64
#  24  dco          float64
#  25  spkts        int64
#  26  dpkts        int64
#  27  sbytes       int64
#  28  dbytes       int64
#  29  rate         float64
#  30  srate        float64
#  31  drate        float64
#  32  attack       int64
#  33  category     object
#  34  subcategory  object
#  35  sipv4_pos1   int64
#  36  sipv4_pos2   int64
#  37  sipv4_pos3   int64
#  38  sipv4_pos4   int64
#  39  sipv6_pos1   int64
#  40  sipv6_pos2   int64
#  41  sipv6_pos3   int64
#  42  sipv6_pos4   int64
#  43  sipv6_pos5   int64
#  44  sipv6_pos6   int64
#  45  sipv6_pos7   int64
#  46  sipv6_pos8   int64
#  47  dipv4_pos1   int64
#  48  dipv4_pos2   int64
#  49  dipv4_pos3   int64
#  50  dipv4_pos4   int64
#  51  dipv6_pos1   int64
#  52  dipv6_pos2   int64
#  53  dipv6_pos3   int64
#  54  dipv6_pos4   int64
#  55  dipv6_pos5   int64
#  56  dipv6_pos6   int64
#  57  dipv6_pos7   int64
#  58  dipv6_pos8   int64
# dtypes: float64(17), int64(33), object(9)
# memory usage: 1.7+ GB

# %% [markdown]
# Besides the 35 original features, in the initial processing of the dataset we added 24 new features that represent the source and destination IP addresses. Each of the IP addresses (source and destination) is represented by 12 features. If the protocol of the address is IPv4, the four features that represent the IPv4 are filled with the decimal value of each position of the address and the eight features that represent the IPv6 are filled with (-1). If the protocol of the address is IPv6, the eight features that represent the IPv6 are filled with the conversion from hexadecimal to decimal of the value in each position of the address and the four features that represent the IPv4 are filled with (-1).
#
# Since we perfomed this process, we can then eliminate the original features **saddr** and **daddr**.

# %%
df = df.drop(["saddr", "daddr"], axis=1)

# %% [markdown]
# Our first approch is to search for features that are not used and thus have only null values, since these features can be eliminated. We also want to eliminate rows that contain null values in any feature.

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# pkSeqID              0
# stime                0
# flgs                 0
# proto                0
# sport              567
# dport              567
# pkts                 0
# bytes                0
# state                0
# ltime                0
# seq                  0
# dur                  0
# mean                 0
# stddev               0
# smac           3860630
# dmac           3860630
# sum                  0
# min                  0
# max                  0
# soui           3860630
# doui           3860630
# sco            3860630
# dco            3860630
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# srate                0
# drate                0
# attack               0
# category             0
# subcategory          0
# sipv4_pos1           0
# sipv4_pos2           0
# sipv4_pos3           0
# sipv4_pos4           0
# sipv6_pos1           0
# sipv6_pos2           0
# sipv6_pos3           0
# sipv6_pos4           0
# sipv6_pos5           0
# sipv6_pos6           0
# sipv6_pos7           0
# sipv6_pos8           0
# dipv4_pos1           0
# dipv4_pos2           0
# dipv4_pos3           0
# dipv4_pos4           0
# dipv6_pos1           0
# dipv6_pos2           0
# dipv6_pos3           0
# dipv6_pos4           0
# dipv6_pos5           0
# dipv6_pos6           0
# dipv6_pos7           0
# dipv6_pos8           0
# dtype: int64

# %% [markdown]
# Since **smac**, **dmac**, **soui**, **doui**, **sco**, **dco** are null for all instances, we can drop those features.

# %%
df = df.drop(["smac", "dmac", "soui", "doui", "sco", "dco"], axis=1)

# %% [markdown]
# We can also drop the rows where **sport** and **dport** are null.

# %%
df = df.dropna(axis=0)

# %% [markdown]
# After performing the drop of the features and rows, we can see that there are no more missing values left.

# %%
df.isnull().sum()
# Out:
# pkSeqID        0
# stime          0
# flgs           0
# proto          0
# sport          0
# dport          0
# pkts           0
# bytes          0
# state          0
# ltime          0
# seq            0
# dur            0
# mean           0
# stddev         0
# sum            0
# min            0
# max            0
# spkts          0
# dpkts          0
# sbytes         0
# dbytes         0
# rate           0
# srate          0
# drate          0
# attack         0
# category       0
# subcategory    0
# sipv4_pos1     0
# sipv4_pos2     0
# sipv4_pos3     0
# sipv4_pos4     0
# sipv6_pos1     0
# sipv6_pos2     0
# sipv6_pos3     0
# sipv6_pos4     0
# sipv6_pos5     0
# sipv6_pos6     0
# sipv6_pos7     0
# sipv6_pos8     0
# dipv4_pos1     0
# dipv4_pos2     0
# dipv4_pos3     0
# dipv4_pos4     0
# dipv6_pos1     0
# dipv6_pos2     0
# dipv6_pos3     0
# dipv6_pos4     0
# dipv6_pos5     0
# dipv6_pos6     0
# dipv6_pos7     0
# dipv6_pos8     0
# dtype: int64

# %% [markdown]
# Besides that, as we are interested only in classify an instance as attack or normal, we can also drop the features **category** and **subcategory**.

# %%
df = df.drop(["category", "subcategory"], axis=1)

# %% [markdown]
# We also want to adjust the data type of the numeric features **sport** and **dport** that currently have the type "object".

# %%
df["sport"] = pd.to_numeric(df["sport"], errors="coerce")
df["dport"] = pd.to_numeric(df["dport"], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3860063 entries, 1 to 3860629
# Data columns (total 49 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   pkSeqID     int64
#  1   stime       float64
#  2   flgs        object
#  3   proto       object
#  4   sport       float64
#  5   dport       float64
#  6   pkts        int64
#  7   bytes       int64
#  8   state       object
#  9   ltime       float64
#  10  seq         int64
#  11  dur         float64
#  12  mean        float64
#  13  stddev      float64
#  14  sum         float64
#  15  min         float64
#  16  max         float64
#  17  spkts       int64
#  18  dpkts       int64
#  19  sbytes      int64
#  20  dbytes      int64
#  21  rate        float64
#  22  srate       float64
#  23  drate       float64
#  24  attack      int64
#  25  sipv4_pos1  int64
#  26  sipv4_pos2  int64
#  27  sipv4_pos3  int64
#  28  sipv4_pos4  int64
#  29  sipv6_pos1  int64
#  30  sipv6_pos2  int64
#  31  sipv6_pos3  int64
#  32  sipv6_pos4  int64
#  33  sipv6_pos5  int64
#  34  sipv6_pos6  int64
#  35  sipv6_pos7  int64
#  36  sipv6_pos8  int64
#  37  dipv4_pos1  int64
#  38  dipv4_pos2  int64
#  39  dipv4_pos3  int64
#  40  dipv4_pos4  int64
#  41  dipv6_pos1  int64
#  42  dipv6_pos2  int64
#  43  dipv6_pos3  int64
#  44  dipv6_pos4  int64
#  45  dipv6_pos5  int64
#  46  dipv6_pos6  int64
#  47  dipv6_pos7  int64
#  48  dipv6_pos8  int64
# dtypes: float64(13), int64(33), object(3)
# memory usage: 1.4+ GB

# %% [markdown]
# This leave us with three categorical features remaining. We can then check for the amount of unique values in each of them to see if we can perform one-hot encoding.

# %%
# Checks the number of unique values in each feature (categorical features)
df.nunique()
# Out:
# pkSeqID       3860063
# stime         3756734
# flgs                9
# proto               4
# sport           65536
# dport            3662
# pkts             1666
# bytes            2709
# state               8
# ltime         3754626
# seq            367328
# dur           1981859
# mean          1412434
# stddev        1015886
# sum           1953296
# min            675648
# max           1264296
# spkts            1407
# dpkts             501
# sbytes           2578
# dbytes            920
# rate           383781
# srate          343033
# drate           31441
# attack              2
# sipv4_pos1          6
# sipv4_pos2          7
# sipv4_pos3          7
# sipv4_pos4         18
# sipv6_pos1          2
# sipv6_pos2          2
# sipv6_pos3          2
# sipv6_pos4          2
# sipv6_pos5          4
# sipv6_pos6          4
# sipv6_pos7          4
# sipv6_pos8          9
# dipv4_pos1         35
# dipv4_pos2         66
# dipv4_pos3         86
# dipv4_pos4        163
# dipv6_pos1          2
# dipv6_pos2          2
# dipv6_pos3          2
# dipv6_pos4          2
# dipv6_pos5          2
# dipv6_pos6          2
# dipv6_pos7          2
# dipv6_pos8          4
# dtype: int64

# %% [markdown]
# Since features **flgs**, **proto** and **state**, which are of type "object", have few unique values, we can convert those into dummies, through one-hot encoding, and then drop the originals.

# %%
df = pd.concat([df, pd.get_dummies(df["flgs"])], axis=1)
df = pd.concat([df, pd.get_dummies(df["proto"])], axis=1)
df = pd.concat([df, pd.get_dummies(df["state"])], axis=1)

# %%
# Drops flgs, proto and state after the conversion
df = df.drop(["flgs", "proto", "state"], axis=1)

# %%
# Removes spaces from the name of the new dummy columns
df.columns = df.columns.str.replace(' ', '')

# %% [markdown]
# Finally, we also want to put the feature **attack** at the last position of the dataframe, since this is our label.

# %%
label = df["attack"]
df = df.drop(["attack"], axis=1)
df = pd.concat([df, label], axis=1)

# %% [markdown]
# To proceed with our EDA, we reset the indexes of the dataframe, considering all the elimination of columns and rows.

# %%
# Resets indexes for visualization purposes only
df = df.reset_index(drop=True)

# %% [markdown]
# For now, we have the following 67 features remaining and 3.860.063 instances.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3860063 entries, 0 to 3860062
# Data columns (total 67 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   pkSeqID     int64
#  1   stime       float64
#  2   sport       float64
#  3   dport       float64
#  4   pkts        int64
#  5   bytes       int64
#  6   ltime       float64
#  7   seq         int64
#  8   dur         float64
#  9   mean        float64
#  10  stddev      float64
#  11  sum         float64
#  12  min         float64
#  13  max         float64
#  14  spkts       int64
#  15  dpkts       int64
#  16  sbytes      int64
#  17  dbytes      int64
#  18  rate        float64
#  19  srate       float64
#  20  drate       float64
#  21  sipv4_pos1  int64
#  22  sipv4_pos2  int64
#  23  sipv4_pos3  int64
#  24  sipv4_pos4  int64
#  25  sipv6_pos1  int64
#  26  sipv6_pos2  int64
#  27  sipv6_pos3  int64
#  28  sipv6_pos4  int64
#  29  sipv6_pos5  int64
#  30  sipv6_pos6  int64
#  31  sipv6_pos7  int64
#  32  sipv6_pos8  int64
#  33  dipv4_pos1  int64
#  34  dipv4_pos2  int64
#  35  dipv4_pos3  int64
#  36  dipv4_pos4  int64
#  37  dipv6_pos1  int64
#  38  dipv6_pos2  int64
#  39  dipv6_pos3  int64
#  40  dipv6_pos4  int64
#  41  dipv6_pos5  int64
#  42  dipv6_pos6  int64
#  43  dipv6_pos7  int64
#  44  dipv6_pos8  int64
#  45  e           uint8
#  46  eF          uint8
#  47  e&          uint8
#  48  e*          uint8
#  49  ed          uint8
#  50  eg          uint8
#  51  er          uint8
#  52  es          uint8
#  53  eU          uint8
#  54  icmp        uint8
#  55  ipv6-icmp   uint8
#  56  tcp         uint8
#  57  udp         uint8
#  58  ACC         uint8
#  59  CON         uint8
#  60  FIN         uint8
#  61  INT         uint8
#  62  NRS         uint8
#  63  REQ         uint8
#  64  RST         uint8
#  65  URP         uint8
#  66  attack      int64
# dtypes: float64(13), int64(33), uint8(21)
# memory usage: 1.4 GB

# %% [markdown]
# Then, we present a matrix that contains the Pearson's correlation coefficient between the 67 features.

# %%
correlation = df.corr()
correlation
# Out:
#              pkSeqID     stime     sport     dport      pkts         bytes  \
# pkSeqID     1.000000  0.213058 -0.000435 -0.039943 -0.028916 -2.816067e-02
# stime       0.213058  1.000000 -0.016000 -0.014497 -0.082662 -7.703821e-02
# sport      -0.000435 -0.016000  1.000000 -0.045988 -0.013904 -1.262462e-02
# dport      -0.039943 -0.014497 -0.045988  1.000000  0.010362  1.046302e-02
# pkts       -0.028916 -0.082662 -0.013904  0.010362  1.000000  9.784706e-01
# bytes      -0.028161 -0.077038 -0.012625  0.010463  0.978471  1.000000e+00
# ltime       0.213135  1.000000 -0.016010 -0.014491 -0.082435 -7.683341e-02
# seq         0.033629  0.049977  0.064793 -0.036356 -0.014568 -1.242436e-02
# dur         0.129568 -0.107607 -0.017642  0.013093  0.455178  4.123406e-01
# mean        0.274696  0.052100  0.002199 -0.010005  0.017457  1.418015e-02
# stddev      0.028306  0.037178 -0.003677  0.002532 -0.003140 -4.512719e-03
# sum         0.068527 -0.151979 -0.013553  0.010434  0.680423  6.110753e-01
# min         0.198470  0.027188  0.004381 -0.009142  0.007913  6.998355e-03
# max         0.224785  0.060267 -0.000192 -0.004834  0.011398  8.277012e-03
# spkts      -0.028602 -0.084689 -0.014531  0.007244  0.942856  8.912278e-01
# dpkts      -0.020967 -0.054749 -0.008703  0.012840  0.807064  8.452060e-01
# sbytes     -0.028769 -0.078910 -0.013082  0.007541  0.935804  9.435965e-01
# dbytes     -0.020253 -0.055068 -0.008782  0.012608  0.806699  8.451118e-01
# rate       -0.003807 -0.005835  0.000134  0.000395  0.002973  2.942992e-03
# ipv6-icmp  -0.000028 -0.004701  1.000000 -0.003850 -0.001696 -0.000015
# tcp         0.005833 -0.998263 -0.004841  0.795237  0.350368 -0.003223
# udp        -0.005833  0.998329 -0.004709 -0.795185 -0.350345 -0.003135
# ACC        -0.000122 -0.020392 -0.000099 -0.016698 -0.007357 -0.000066
# CON        -0.000209 -0.034840 -0.000169 -0.028529 -0.012569 -0.000112
# FIN         1.000000 -0.005823 -0.000028 -0.004768 -0.002101 -0.000019
# INT        -0.005823  1.000000 -0.004701 -0.793856 -0.349760 -0.003130
# NRS        -0.000028 -0.004701  1.000000 -0.003850 -0.001696 -0.000015
# REQ        -0.004768 -0.793856 -0.003850  1.000000 -0.286399 -0.002563
# RST        -0.002101 -0.349760 -0.001696 -0.286399  1.000000 -0.001129
# URP        -0.000019 -0.003130 -0.000015 -0.002563 -0.001129  1.000000
# attack     -0.121846  0.005005 -0.098375  0.039132  0.016987 -0.014994
#
#               attack
# pkSeqID     0.185595
# stime       0.790053
# sport       0.001621
# dport      -0.027282
# pkts       -0.175511
# bytes      -0.160482
# ltime       0.790034
# seq         0.060383
# dur        -0.122714
# mean        0.022494
# stddev      0.035310
# sum        -0.179016
# min         0.008428
# max         0.038498
# spkts      -0.179683
# dpkts      -0.116482
# sbytes     -0.163585
# dbytes     -0.116001
# rate       -0.026152
# srate      -0.042031
# drate      -0.146646
# sipv4_pos1  0.140836
# sipv4_pos2  0.138398
# sipv4_pos3  0.134187
# sipv4_pos4  0.668346
# sipv6_pos1 -0.138332
# sipv6_pos2 -0.138332
# sipv6_pos3 -0.138332
# sipv6_pos4 -0.138332
# sipv6_pos5 -0.068047
# sipv6_pos6 -0.125669
# sipv6_pos7 -0.130075
# sipv6_pos8 -0.115818
# dipv4_pos1  0.466108
# dipv4_pos2  0.456114
# dipv4_pos3 -0.141850
# dipv4_pos4 -0.491404
# dipv6_pos1 -0.138332
# dipv6_pos2 -0.138332
# dipv6_pos3 -0.138332
# dipv6_pos4 -0.138332
# dipv6_pos5 -0.138332
# dipv6_pos6 -0.138332
# dipv6_pos7 -0.138332
# dipv6_pos8 -0.096204
# e          -0.039992
# eF         -0.033162
# e&         -0.078476
# e*         -0.091065
# ed         -0.033293
# eg         -0.003417
# er         -0.010487
# es          0.043694
# eU          0.001964
# icmp       -0.014994
# ipv6-icmp  -0.098375
# tcp         0.030481
# udp        -0.029447
# ACC         0.001005
# CON        -0.729034
# FIN        -0.121846
# INT         0.005005
# NRS        -0.098375
# REQ         0.039132
# RST         0.016987
# URP        -0.014994
# attack      1.000000
#
# [67 rows x 67 columns]

# %% [markdown]
# The correlation coefficient between two features is expressed as number between (-1) and (+1), where the (-1) represents the strongest negative correlation, (+1) represents the strongest positive correlation and 0 represents no correlation at all.
#
# Considering this, we established a threshold _t = 0.5_ for the value of the correlation between any feature and the label **attack**. Meaning that, if the absolute value of the correlation between a feature and the label is less than _t_, this feature can be eliminated/droped, since it possesses a weak relationship with the target.

# %%
# Correlation of all features with the label feature
corr_label = abs(correlation["attack"])

# Selects the features that strong relates to the label based on the established threshold
threshold = 0.5
strong_features = corr_label[corr_label >= threshold]
strong_features
# Out:
# stime         0.790053
# ltime         0.790034
# sipv4_pos4    0.668346
# CON           0.729034
# attack        1.000000
# Name: attack, dtype: float64

# %% [markdown]
# After selecting the features that have a strong relationship with the label/target, we create a new dataset that contains only these features and the label.

# %%
data = df[["stime", "ltime", "sipv4_pos4", "CON", "attack"]]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3860063 entries, 0 to 3860062
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   stime       float64
#  1   ltime       float64
#  2   sipv4_pos4  int64
#  3   CON         uint8
#  4   attack      int64
# dtypes: float64(2), int64(2), uint8(1)
# memory usage: 121.5 MB

# %% [markdown]
# Considering the reduced amount of features, now we can also present the heatmap of the correlation between all features.

# %%
# Creates a mask to show only the lower triangle of the heatmap
correlation = data.corr()
mask = np.triu(correlation)

sns.heatmap(correlation, annot=True, linewidths=.5, cmap="vlag", mask=mask)
plt.show()

# %% [markdown]
# As we can see from the heatmap, features **stime** and **ltime** have the strongest correlation possible. So, we can drop one of them, as they bring duplicated information. If any other two features had had a correlation coefficient bigger than the threshold, we would drop one of them, as well.
#
# In this case, we chose to drop **ltime**.

# %%
data = data.drop(["ltime"], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3860063 entries, 0 to 3860062
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   stime       float64
#  1   sipv4_pos4  int64
#  2   CON         uint8
#  3   attack      int64
# dtypes: float64(1), int64(2), uint8(1)
# memory usage: 92.0 MB

# %% [markdown]
# Next, we present additional information about the final dataset structure we achieved after the feature selection process.

# %%
data.head(n=10).T
# Out:
#                        0             1             2             3  \
# stime       1.526344e+09  1.526344e+09  1.526344e+09  1.526344e+09
# sipv4_pos4  7.000000e+00  1.490000e+02  2.700000e+01  1.500000e+02
# CON         1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# attack      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                        4             5             6             7  \
# stime       1.526344e+09  1.526344e+09  1.526344e+09  1.526344e+09
# sipv4_pos4  1.490000e+02  7.000000e+00  1.500000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# attack      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#
#                        8             9
# stime       1.526344e+09  1.526344e+09
# sipv4_pos4  1.490000e+02  1.470000e+02
# CON         1.000000e+00  0.000000e+00
# attack      0.000000e+00  0.000000e+00

# %%
data.sample(frac=0.0001, random_state=1).T
# Out:
#                  1458215       23868         614350        1998902  \
# stime       1.528097e+09  1.528096e+09  1.528096e+09  1.528099e+09
# sipv4_pos4  1.470000e+02  1.480000e+02  1.490000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  1785518       1489495       2273219       345751   \
# stime       1.528098e+09  1.528097e+09  1.528100e+09  1.528096e+09
# sipv4_pos4  1.490000e+02  1.490000e+02  1.480000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  2866537       3171325       527251        864366   \
# stime       1.528100e+09  1.528100e+09  1.528096e+09  1.528097e+09
# sipv4_pos4  1.490000e+02  1.490000e+02  1.500000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  1006940       996869        882522        1189959  \
# stime       1.528097e+09  1.528097e+09  1.528097e+09  1.528097e+09
# sipv4_pos4  1.470000e+02  1.480000e+02  1.470000e+02  1.490000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  507575        2085549       2186672       862362   \
# stime       1.528096e+09  1.528099e+09  1.528099e+09  1.528097e+09
# sipv4_pos4  1.480000e+02  1.480000e+02  1.490000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  871138        1546426       273124        626349   \
# stime       1.528097e+09  1.528098e+09  1.528096e+09  1.528096e+09
# sipv4_pos4  1.500000e+02  1.470000e+02  1.500000e+02  1.500000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  2007419  ...       3377242       3605524       272091   \
# stime       1.528099e+09  ...  1.528101e+09  1.528101e+09  1.528096e+09
# sipv4_pos4  1.470000e+02  ...  1.490000e+02  1.480000e+02  1.490000e+02
# CON         0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  ...  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  661948        1117598       858369        82403    \
# stime       1.528096e+09  1.528097e+09  1.528097e+09  1.528096e+09
# sipv4_pos4  1.490000e+02  1.480000e+02  1.470000e+02  1.500000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  3433113       2108929       3546004       2836784  \
# stime       1.528101e+09  1.528099e+09  1.528101e+09  1.528100e+09
# sipv4_pos4  1.480000e+02  1.470000e+02  1.480000e+02  1.480000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  2919109       163978        899319        3695301  \
# stime       1.528100e+09  1.528096e+09  1.528097e+09  1.528102e+09
# sipv4_pos4  1.490000e+02  1.470000e+02  1.470000e+02  1.500000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  2618548       418181        1080837       117752   \
# stime       1.528100e+09  1.528096e+09  1.528097e+09  1.528096e+09
# sipv4_pos4  1.500000e+02  1.500000e+02  1.500000e+02  1.500000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  2450053       1496149       761926        1386619  \
# stime       1.528100e+09  1.528097e+09  1.528097e+09  1.528097e+09
# sipv4_pos4  1.500000e+02  1.500000e+02  1.500000e+02  1.470000e+02
# CON         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
#                  155384        2614426
# stime       1.528096e+09  1.528100e+09
# sipv4_pos4  1.480000e+02  1.500000e+02
# CON         0.000000e+00  0.000000e+00
# attack      1.000000e+00  1.000000e+00
#
# [4 rows x 386 columns]

# %%
data.describe().T
# Out:
#                 count          mean           std           min           25%  \
# stime       3860063.0  1.528096e+09  52719.261464  1.526344e+09  1.528097e+09
# sipv4_pos4  3860063.0  1.481170e+02      7.411189 -1.000000e+00  1.470000e+02
# CON         3860063.0  1.250498e-03      0.035340  0.000000e+00  0.000000e+00
# attack      3860063.0  9.976498e-01      0.048422  0.000000e+00  1.000000e+00
#
#                      50%           75%           max
# stime       1.528098e+09  1.528100e+09  1.529382e+09
# sipv4_pos4  1.480000e+02  1.490000e+02  2.410000e+02
# CON         0.000000e+00  0.000000e+00  1.000000e+00
# attack      1.000000e+00  1.000000e+00  1.000000e+00

# %%
data.sipv4_pos4.value_counts()
# Out:
#  147    963623
#  150    962202
#  149    961919
#  148    961721
#  3        5327
#  7        2810
#  46        894
#  6         574
#  5         446
#  55        218
# -1         174
#  4          79
#  27         69
#  193         2
#  69          2
#  78          1
#  65          1
#  241         1
# Name: sipv4_pos4, dtype: int64

# %%
data.CON.value_counts()
# Out:
# 0    3855236
# 1       4827
# Name: CON, dtype: int64

# %%
data.attack.value_counts()
# Out:
# 1    3850991
# 0       9072
# Name: attack, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Conclusions
#
# We presented our Exploratory Data Analysis of the BoT-IoT dataset, which lead us to achieve a final dataset structure that contains only three features (**stime**, **sipv4_pos4** and **CON**) plus the label. Our intention was to analyse a subset of the whole dataset and perform the feature selection process. This process guided us in a appropriate manner to filter and adjust the data to meet the characteristics that are needed by the ensemble methods we intend to use for our data stream classification.
#
# Through the result of this EDA, we will perform an advanced processing on the BoT-IoT dataset to generate the final data file that will be used in our experiments.

# %% [markdown]
# ---
